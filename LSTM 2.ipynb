# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import joblib
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Define folder paths for each batting shot category
folders = {
    "cover_drive": "./cover_drive",
    "pull_shot": "./pull_shot",
    "wrong_shot": "./wrong_shot"
}

# %%
def load_and_preprocess_data(folders):
    sequences = []
    labels = []
    
    for label, folder_path in enumerate(folders.values()):
        print(f"Processing folder: {folder_path}, Label: {label}")
        
        for file in os.listdir(folder_path):
            if file.endswith(".xlsx"):
                file_path = os.path.join(folder_path, file)
                
                try:
                    df = pd.read_excel(file_path)
                    # Extract features as sequences
                    sequence = df[["Time","LShoulder_Avg", "LElbow_Avg"]].values
                    sequences.append(sequence)
                    labels.append(label)
                except KeyError:
                    print(f"Missing columns in {file_path}, skipping this file.")
    
    return sequences, labels

# %%
def pad_sequences(sequences, max_length=None):
    if max_length is None:
        max_length = max(len(seq) for seq in sequences)
    
    padded_sequences = []
    for seq in sequences:
        if len(seq) > max_length:
            padded_sequences.append(seq[:max_length])
        else:
            padding_length = max_length - len(seq)
            padded_seq = np.pad(seq, ((0, padding_length), (0, 0)), mode='constant')
            padded_sequences.append(padded_seq)
    
    return np.array(padded_sequences)

# %%
def create_lstm_model(sequence_length, n_features, n_classes):
    model = Sequential([
        LSTM(64, input_shape=(sequence_length, n_features), return_sequences=True),
        Dropout(0.2),
        LSTM(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(n_classes, activation='softmax')  # softmax for multi-class
    ])
    
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Load and preprocess data
sequences, labels = load_and_preprocess_data(folders)
# Out:
# Processing folder: ./cover_drive, Label: 0
# Processing folder: ./pull_shot, Label: 1
# Processing folder: ./wrong_shot, Label: 2

# %%
# Pad sequences to uniform length
padded_sequences = pad_sequences(sequences)

# %%
# Split features into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, 
    np.array(labels), 
    test_size=0.2, 
    random_state=42
)

# %%
# Normalize the features
scaler = StandardScaler()

# %%
# Reshape for scaling
X_train_reshaped = X_train.reshape(-1, X_train.shape[-1])
X_test_reshaped = X_test.reshape(-1, X_test.shape[-1])

# %%
# Fit and transform
X_train_scaled = scaler.fit_transform(X_train_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped)

# %%
# Reshape back to 3D
X_train_scaled = X_train_scaled.reshape(X_train.shape)
X_test_scaled = X_test_scaled.reshape(X_test.shape)

# %%
# Create and train the model
n_features = X_train.shape[2]
n_classes = len(np.unique(labels))
sequence_length = X_train.shape[1]

model = create_lstm_model(sequence_length, n_features, n_classes)

# %%
# Train the model
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,
    epochs=80,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/80
# 6/6 [==============================] - 10s 1s/step - loss: 1.0443 - accuracy: 0.4667 - val_loss: 1.0314 - val_accuracy: 0.4565
# Epoch 2/80
# 6/6 [==============================] - 5s 855ms/step - loss: 0.9680 - accuracy: 0.4500 - val_loss: 1.0813 - val_accuracy: 0.4565
# Epoch 3/80
# 6/6 [==============================] - 5s 926ms/step - loss: 0.9647 - accuracy: 0.4556 - val_loss: 1.0662 - val_accuracy: 0.4565
# Epoch 4/80
# 6/6 [==============================] - 5s 881ms/step - loss: 0.9662 - accuracy: 0.4611 - val_loss: 1.0530 - val_accuracy: 0.4565
# Epoch 5/80
# 6/6 [==============================] - 6s 907ms/step - loss: 0.9638 - accuracy: 0.4222 - val_loss: 1.0471 - val_accuracy: 0.4565
# Epoch 6/80
# 6/6 [==============================] - 5s 887ms/step - loss: 0.9682 - accuracy: 0.4389 - val_loss: 1.0433 - val_accuracy: 0.4565
# Epoch 7/80
# 6/6 [==============================] - 5s 879ms/step - loss: 0.9546 - accuracy: 0.4667 - val_loss: 1.0465 - val_accuracy: 0.4565
# Epoch 8/80
# 6/6 [==============================] - 6s 958ms/step - loss: 0.9631 - accuracy: 0.5000 - val_loss: 1.0635 - val_accuracy: 0.4565
# Epoch 9/80
# 6/6 [==============================] - 5s 902ms/step - loss: 0.9611 - accuracy: 0.4667 - val_loss: 1.0564 - val_accuracy: 0.4565
# Epoch 10/80
# 6/6 [==============================] - 5s 922ms/step - loss: 0.9562 - accuracy: 0.4667 - val_loss: 1.0486 - val_accuracy: 0.4565
# Epoch 11/80
# 6/6 [==============================] - 5s 870ms/step - loss: 0.9551 - accuracy: 0.4667 - val_loss: 1.0498 - val_accuracy: 0.4565
# Epoch 12/80
# 6/6 [==============================] - 6s 932ms/step - loss: 0.9598 - accuracy: 0.4667 - val_loss: 1.0618 - val_accuracy: 0.4565
# Epoch 13/80
# 6/6 [==============================] - 5s 859ms/step - loss: 0.9579 - accuracy: 0.4611 - val_loss: 1.0599 - val_accuracy: 0.4565
# Epoch 14/80
# 6/6 [==============================] - 5s 930ms/step - loss: 0.9458 - accuracy: 0.5056 - val_loss: 1.0592 - val_accuracy: 0.4565
# Epoch 15/80
# 6/6 [==============================] - 5s 923ms/step - loss: 0.9551 - accuracy: 0.4611 - val_loss: 1.0494 - val_accuracy: 0.4565
# Epoch 16/80
# 6/6 [==============================] - 5s 886ms/step - loss: 0.9451 - accuracy: 0.4389 - val_loss: 1.0517 - val_accuracy: 0.4565
# Epoch 17/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9569 - accuracy: 0.4667 - val_loss: 1.0561 - val_accuracy: 0.4565
# Epoch 18/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9544 - accuracy: 0.5222 - val_loss: 1.0582 - val_accuracy: 0.4565
# Epoch 19/80
# 6/6 [==============================] - 6s 960ms/step - loss: 0.9676 - accuracy: 0.4056 - val_loss: 1.0565 - val_accuracy: 0.4565
# Epoch 20/80
# 6/6 [==============================] - 6s 975ms/step - loss: 0.9507 - accuracy: 0.4611 - val_loss: 1.0500 - val_accuracy: 0.4565
# Epoch 21/80
# 6/6 [==============================] - 5s 894ms/step - loss: 0.9544 - accuracy: 0.4944 - val_loss: 1.0487 - val_accuracy: 0.4565
# Epoch 22/80
# 6/6 [==============================] - 6s 948ms/step - loss: 0.9610 - accuracy: 0.4333 - val_loss: 1.0475 - val_accuracy: 0.4565
# Epoch 23/80
# 6/6 [==============================] - 6s 956ms/step - loss: 0.9605 - accuracy: 0.4778 - val_loss: 1.0535 - val_accuracy: 0.4565
# Epoch 24/80
# 6/6 [==============================] - 5s 895ms/step - loss: 0.9614 - accuracy: 0.4278 - val_loss: 1.0570 - val_accuracy: 0.4565
# Epoch 25/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9614 - accuracy: 0.4500 - val_loss: 1.0452 - val_accuracy: 0.4565
# Epoch 26/80
# 6/6 [==============================] - 5s 898ms/step - loss: 0.9562 - accuracy: 0.4278 - val_loss: 1.0525 - val_accuracy: 0.4565
# Epoch 27/80
# 6/6 [==============================] - 6s 908ms/step - loss: 0.9450 - accuracy: 0.4278 - val_loss: 1.0548 - val_accuracy: 0.4565
# Epoch 28/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9577 - accuracy: 0.5000 - val_loss: 1.0612 - val_accuracy: 0.4565
# Epoch 29/80
# 6/6 [==============================] - 5s 890ms/step - loss: 0.9621 - accuracy: 0.4389 - val_loss: 1.0550 - val_accuracy: 0.4565
# Epoch 30/80
# 6/6 [==============================] - 6s 975ms/step - loss: 0.9575 - accuracy: 0.4278 - val_loss: 1.0562 - val_accuracy: 0.4565
# Epoch 31/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9527 - accuracy: 0.4889 - val_loss: 1.0519 - val_accuracy: 0.4565
# Epoch 32/80
# 6/6 [==============================] - 6s 978ms/step - loss: 0.9499 - accuracy: 0.4778 - val_loss: 1.0527 - val_accuracy: 0.4565
# Epoch 33/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9622 - accuracy: 0.4333 - val_loss: 1.0544 - val_accuracy: 0.4565
# Epoch 34/80
# 6/6 [==============================] - 6s 996ms/step - loss: 0.9566 - accuracy: 0.4389 - val_loss: 1.0610 - val_accuracy: 0.4565
# Epoch 35/80
# 6/6 [==============================] - 8s 1s/step - loss: 0.9564 - accuracy: 0.4278 - val_loss: 1.0516 - val_accuracy: 0.4565
# Epoch 36/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9535 - accuracy: 0.4556 - val_loss: 1.0513 - val_accuracy: 0.4565
# Epoch 37/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9566 - accuracy: 0.4056 - val_loss: 1.0547 - val_accuracy: 0.4565
# Epoch 38/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9464 - accuracy: 0.4722 - val_loss: 1.0545 - val_accuracy: 0.4565
# Epoch 39/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9560 - accuracy: 0.4278 - val_loss: 1.0562 - val_accuracy: 0.4565
# Epoch 40/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9520 - accuracy: 0.4333 - val_loss: 1.0474 - val_accuracy: 0.4565
# Epoch 41/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9443 - accuracy: 0.5000 - val_loss: 1.0478 - val_accuracy: 0.4565
# Epoch 42/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9563 - accuracy: 0.4500 - val_loss: 1.0485 - val_accuracy: 0.4565
# Epoch 43/80
# 6/6 [==============================] - 5s 914ms/step - loss: 0.9587 - accuracy: 0.4500 - val_loss: 1.0560 - val_accuracy: 0.4565
# Epoch 44/80
# 6/6 [==============================] - 6s 987ms/step - loss: 0.9524 - accuracy: 0.4611 - val_loss: 1.0520 - val_accuracy: 0.4565
# Epoch 45/80
# 6/6 [==============================] - 6s 999ms/step - loss: 0.9523 - accuracy: 0.4667 - val_loss: 1.0563 - val_accuracy: 0.4565
# Epoch 46/80
# 6/6 [==============================] - 6s 953ms/step - loss: 0.9557 - accuracy: 0.4444 - val_loss: 1.0531 - val_accuracy: 0.4565
# Epoch 47/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9537 - accuracy: 0.5056 - val_loss: 1.0531 - val_accuracy: 0.4565
# Epoch 48/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9596 - accuracy: 0.4056 - val_loss: 1.0551 - val_accuracy: 0.3696
# Epoch 49/80
# 6/6 [==============================] - 8s 1s/step - loss: 0.9574 - accuracy: 0.4778 - val_loss: 1.0560 - val_accuracy: 0.3696
# Epoch 50/80
# 6/6 [==============================] - 8s 1s/step - loss: 0.9430 - accuracy: 0.4611 - val_loss: 1.0563 - val_accuracy: 0.3696
# Epoch 51/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9561 - accuracy: 0.4500 - val_loss: 1.0671 - val_accuracy: 0.3696
# Epoch 52/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9608 - accuracy: 0.5278 - val_loss: 1.0588 - val_accuracy: 0.4565
# Epoch 53/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9513 - accuracy: 0.4556 - val_loss: 1.0516 - val_accuracy: 0.4565
# Epoch 54/80
# 6/6 [==============================] - 8s 1s/step - loss: 0.9507 - accuracy: 0.4611 - val_loss: 1.0518 - val_accuracy: 0.4565
# Epoch 55/80
# 6/6 [==============================] - 6s 1s/step - loss: 0.9517 - accuracy: 0.4611 - val_loss: 1.0510 - val_accuracy: 0.4565
# Epoch 56/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9561 - accuracy: 0.4444 - val_loss: 1.0590 - val_accuracy: 0.4565
# Epoch 57/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9535 - accuracy: 0.5000 - val_loss: 1.0557 - val_accuracy: 0.4565
# Epoch 58/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9508 - accuracy: 0.4722 - val_loss: 1.0546 - val_accuracy: 0.4565
# Epoch 59/80
# 6/6 [==============================] - 7s 1s/step - loss: 0.9596 - accuracy: 0.4500 - val_loss: 1.0558 - val_accuracy: 0.4565
# Epoch 60/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9561 - accuracy: 0.4500 - val_loss: 1.0487 - val_accuracy: 0.4565
# Epoch 61/80
# 6/6 [==============================] - 8s 1s/step - loss: 0.9582 - accuracy: 0.4611 - val_loss: 1.0519 - val_accuracy: 0.4565
# Epoch 62/80
# 6/6 [==============================] - 10s 2s/step - loss: 0.9496 - accuracy: 0.4389 - val_loss: 1.0525 - val_accuracy: 0.4565
# Epoch 63/80
# 6/6 [==============================] - 10s 2s/step - loss: 0.9580 - accuracy: 0.4167 - val_loss: 1.0542 - val_accuracy: 0.4565
# Epoch 64/80
# 6/6 [==============================] - 10s 2s/step - loss: 0.9599 - accuracy: 0.4556 - val_loss: 1.0515 - val_accuracy: 0.4565
# Epoch 65/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9508 - accuracy: 0.4444 - val_loss: 1.0544 - val_accuracy: 0.4565
# Epoch 66/80
# 6/6 [==============================] - 9s 1s/step - loss: 0.9528 - accuracy: 0.4389 - val_loss: 1.0562 - val_accuracy: 0.4565
# Epoch 67/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9551 - accuracy: 0.4611 - val_loss: 1.0574 - val_accuracy: 0.4565
# Epoch 68/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9511 - accuracy: 0.5056 - val_loss: 1.0565 - val_accuracy: 0.4565
# Epoch 69/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9561 - accuracy: 0.4278 - val_loss: 1.0524 - val_accuracy: 0.4565
# Epoch 70/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9603 - accuracy: 0.4833 - val_loss: 1.0509 - val_accuracy: 0.4565
# Epoch 71/80
# 6/6 [==============================] - 10s 2s/step - loss: 0.9625 - accuracy: 0.3667 - val_loss: 1.0507 - val_accuracy: 0.4565
# Epoch 72/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9596 - accuracy: 0.4667 - val_loss: 1.0509 - val_accuracy: 0.4565
# Epoch 73/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9507 - accuracy: 0.5000 - val_loss: 1.0481 - val_accuracy: 0.4565
# Epoch 74/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9541 - accuracy: 0.4389 - val_loss: 1.0502 - val_accuracy: 0.4565
# Epoch 75/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9566 - accuracy: 0.4556 - val_loss: 1.0546 - val_accuracy: 0.4565
# Epoch 76/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9535 - accuracy: 0.4667 - val_loss: 1.0623 - val_accuracy: 0.4565
# Epoch 77/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9531 - accuracy: 0.3889 - val_loss: 1.0621 - val_accuracy: 0.4565
# Epoch 78/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9515 - accuracy: 0.4278 - val_loss: 1.0516 - val_accuracy: 0.4565
# Epoch 79/80
# 6/6 [==============================] - 9s 2s/step - loss: 0.9506 - accuracy: 0.4389 - val_loss: 1.0502 - val_accuracy: 0.4565
# Epoch 80/80
# 6/6 [==============================] - 9s 1s/step - loss: 0.9525 - accuracy: 0.4278 - val_loss: 1.0510 - val_accuracy: 0.4565

# %%
# Evaluate the model
y_pred = np.argmax(model.predict(X_test_scaled), axis=1)
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[25  0  0]
#  [24  0  0]
#  [ 8  0  0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61        25
#            1       0.00      0.00      0.00        24
#            2       0.00      0.00      0.00         8
#
#     accuracy                           0.44        57
#    macro avg       0.15      0.33      0.20        57
# weighted avg       0.19      0.44      0.27        57
#
#
# Accuracy Score: 0.43859649122807015
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
